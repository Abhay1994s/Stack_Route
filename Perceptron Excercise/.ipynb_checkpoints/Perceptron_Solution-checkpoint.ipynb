# %% [markdown]
# # PERCEPTRON BASIC EXERCISES

# %% [markdown]
# ## Importing necessary modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from matplotlib import animation
# %matplotlib nbagg
#%matplotlib inline
import math

# %% [markdown]
# ## Importing files

# %%
data_set_1 = pd.read_csv("datafile1.csv", names = ["X1","X2","Y"])
data_set_2 = pd.read_csv("datafile2.csv", names = ["X1","X2","Y"])
data_set_3 = pd.read_csv("datafile3.csv", names = ["X1","X2","Y"])
data_set_4 = pd.read_csv("datafile4.csv", names = ["X1","X2","Y"])

# %% [markdown]
# # First DataSet

# %%
plt.scatter(data_set_1['X1'], data_set_1['X2'], c = data_set_1['Y'])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Feature Plot X1 vs X2')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## This Plot can be linearly separable

# %%
x_values = []
y_actual = []
for i in data_set_1.iterrows():
    x1 = i[1][0]
    x2 = i[1][1]
    y = i[1][2]
    x_values.append(np.array([x1,x2,1]))
    y_actual.append(np.array(y).reshape(1))
x_values[0]
# Out:
# array([ 0.47434107, -1.16463056,  1.        ])

# %%
# Estimate Perceptron weights using stochastic gradient descent
def train_weights(train, l_rate, n_epoch):
    weights_plot = []
    w1 = np.random.random_sample() # weight 1 coresponding to X1
    w2 = np.random.random_sample() # weight 2 coresponding to X2
    bias = np.random.random_sample() # bias
    for epoch in range(n_epoch):
        sum_error = 0.0
        weights_plot.append(np.array([bias,w1,w2]).reshape(3,1))
        for i in data_set_1.iterrows():
            X_1 = i[1][0]
            X_2 = i[1][1]
            Y_actual = i[1][2]
            #print("Actual X1 is: ", X_1 ,", Actual X2 is: " ,X_2, ",Actual Y is: ", Y_actual)
            activation_value = (w1*X_1)+(w2*X_2)+bias
            if activation_value >=0:
                Y_predicted = 1
            else:
                Y_predicted = 0
            error = Y_actual - Y_predicted
            sum_error += error**2
            w1 = w1 + (error*X_1*l_rate)
            w2 = w2 + (error*X_2*l_rate)
            bias = bias + error
        print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
    return bias,w1,w2,weights_plot

# %%
# Calculate Weights
l_rate = 0.1
n_epoch = 20
bias_1, w1_1, w2_1, weights_plot_1 = train_weights(data_set_1, l_rate, n_epoch)
print(bias_1,w1_1,w2_1)
# Out:
# >epoch=0, lrate=0.100, error=2.000
# >epoch=1, lrate=0.100, error=4.000
# >epoch=2, lrate=0.100, error=3.000
# >epoch=3, lrate=0.100, error=2.000
# >epoch=4, lrate=0.100, error=2.000
# >epoch=5, lrate=0.100, error=2.000
# >epoch=6, lrate=0.100, error=0.000
# >epoch=7, lrate=0.100, error=0.000
# >epoch=8, lrate=0.100, error=0.000
# >epoch=9, lrate=0.100, error=0.000
# >epoch=10, lrate=0.100, error=0.000
# >epoch=11, lrate=0.100, error=0.000
# >epoch=12, lrate=0.100, error=0.000
# >epoch=13, lrate=0.100, error=0.000
# >epoch=14, lrate=0.100, error=0.000
# >epoch=15, lrate=0.100, error=0.000
# >epoch=16, lrate=0.100, error=0.000
# >epoch=17, lrate=0.100, error=0.000
# >epoch=18, lrate=0.100, error=0.000
# >epoch=19, lrate=0.100, error=0.000
# -0.755115229005 0.456536369616 1.24009752121

# %%
# Equation of a line
#-(bias1_1/w2_1) + -((w1_1*x1)/w2_1) = x2

# %%
plt.plot(data_set_1['X1'], -(bias_1/w2_1) -((w1_1*data_set_1['X1'])/w2_1), color='red')
plt.scatter(data_set_1['X1'], data_set_1['X2'], c = data_set_1['Y'])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Feature Plot X1 vs X2')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Animated Plot

# %%
#First set up the figure, the axis, and the plot element we want to animate

fig = plt.figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

ax.scatter(data_set_1['X1'], data_set_1['X2'], c = data_set_1['Y'])
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = data_set_1['X1']
    y = -(weights_plot_1[i][0]/weights_plot_1[i][2]) -((weights_plot_1[i][1]*x)/weights_plot_1[i][2])
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
ani = animation.FuncAnimation(fig, animate, init_func=init, frames=len(weights_plot_1), interval=20, blit=True,repeat = False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## DataSet  2

# %% [markdown]
# ### Scatter Plot

# %%
plt.scatter(data_set_2['X1'], data_set_2['X2'], c = data_set_2['Y'])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Feature Plot')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## Can be linearly separable

# %%
bias_2, w1_2, w2_2, weights_plot_2 = train_weights(data_set_2, l_rate, n_epoch)
print(bias_2,w1_2,w2_2)
# Out:
# >epoch=0, lrate=0.100, error=5.000
# >epoch=1, lrate=0.100, error=2.000
# >epoch=2, lrate=0.100, error=0.000
# >epoch=3, lrate=0.100, error=0.000
# >epoch=4, lrate=0.100, error=0.000
# >epoch=5, lrate=0.100, error=0.000
# >epoch=6, lrate=0.100, error=0.000
# >epoch=7, lrate=0.100, error=0.000
# >epoch=8, lrate=0.100, error=0.000
# >epoch=9, lrate=0.100, error=0.000
# >epoch=10, lrate=0.100, error=0.000
# >epoch=11, lrate=0.100, error=0.000
# >epoch=12, lrate=0.100, error=0.000
# >epoch=13, lrate=0.100, error=0.000
# >epoch=14, lrate=0.100, error=0.000
# >epoch=15, lrate=0.100, error=0.000
# >epoch=16, lrate=0.100, error=0.000
# >epoch=17, lrate=0.100, error=0.000
# >epoch=18, lrate=0.100, error=0.000
# >epoch=19, lrate=0.100, error=0.000
# -0.223726657245 0.226988557594 0.610736854449

# %%
### Bias is -0.96798347806550833, weight1 is 0.6099330327192356 and weight2 is 1.588051474557912 for dataSet 2

# %%
plt.plot(data_set_2['X1'], -(bias_2/w2_2) -((w1_2*data_set_2['X1'])/w2_2), color='red')
plt.scatter(data_set_2['X1'], data_set_2['X2'], c = data_set_2['Y'])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Feature Plot X1 vs X2')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Animated Plot

# %%
#First set up the figure, the axis, and the plot element we want to animate

fig = plt.figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

ax.scatter(data_set_2['X1'], data_set_2['X2'], c = data_set_2['Y'])
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = data_set_2['X1']
    y = -(weights_plot_2[i][0]/weights_plot_2[i][2]) -((weights_plot_2[i][1]*x)/weights_plot_2[i][2])
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
ani_2 = animation.FuncAnimation(fig, animate, init_func=init, frames=len(weights_plot_2), interval=20, blit=True,repeat=False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## DataSet 3

# %% [markdown]
# ### Scatter Plot

# %%
plt.scatter(data_set_3['X1'], data_set_3['X2'], c = data_set_3['Y'])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Feature Plot')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## can't be linearly separable

# %%
bias_3, w1_3, w2_3, weights_plot_3 = train_weights(data_set_3, l_rate, n_epoch)
print(bias_3,w1_3,w2_3)
# Out:
# >epoch=0, lrate=0.100, error=2.000
# >epoch=1, lrate=0.100, error=1.000
# >epoch=2, lrate=0.100, error=0.000
# >epoch=3, lrate=0.100, error=0.000
# >epoch=4, lrate=0.100, error=0.000
# >epoch=5, lrate=0.100, error=0.000
# >epoch=6, lrate=0.100, error=0.000
# >epoch=7, lrate=0.100, error=0.000
# >epoch=8, lrate=0.100, error=0.000
# >epoch=9, lrate=0.100, error=0.000
# >epoch=10, lrate=0.100, error=0.000
# >epoch=11, lrate=0.100, error=0.000
# >epoch=12, lrate=0.100, error=0.000
# >epoch=13, lrate=0.100, error=0.000
# >epoch=14, lrate=0.100, error=0.000
# >epoch=15, lrate=0.100, error=0.000
# >epoch=16, lrate=0.100, error=0.000
# >epoch=17, lrate=0.100, error=0.000
# >epoch=18, lrate=0.100, error=0.000
# >epoch=19, lrate=0.100, error=0.000
# -0.777854838947 0.466909527302 1.10350398011

# %%
plt.plot(data_set_3['X1'], -(bias_3/w2_3) -((w1_3*data_set_3['X1'])/w2_3), color='red')
plt.scatter(data_set_3['X1'], data_set_3['X2'], c = data_set_3['Y'])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Feature Plot X1 vs X2')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## DataSet 4

# %% [markdown]
# ### Scatter Plot

# %%
plt.scatter(data_set_4['X1'], data_set_4['X2'], c = data_set_4['Y'])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Feature Plot')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## can't be linearly separable

# %%
bias_4, w1_4, w2_4, weights_plot_4 = train_weights(data_set_4, l_rate, n_epoch)
print(bias_4,w1_4,w2_4)
# Out:
# >epoch=0, lrate=0.100, error=7.000
# >epoch=1, lrate=0.100, error=2.000
# >epoch=2, lrate=0.100, error=2.000
# >epoch=3, lrate=0.100, error=0.000
# >epoch=4, lrate=0.100, error=0.000
# >epoch=5, lrate=0.100, error=0.000
# >epoch=6, lrate=0.100, error=0.000
# >epoch=7, lrate=0.100, error=0.000
# >epoch=8, lrate=0.100, error=0.000
# >epoch=9, lrate=0.100, error=0.000
# >epoch=10, lrate=0.100, error=0.000
# >epoch=11, lrate=0.100, error=0.000
# >epoch=12, lrate=0.100, error=0.000
# >epoch=13, lrate=0.100, error=0.000
# >epoch=14, lrate=0.100, error=0.000
# >epoch=15, lrate=0.100, error=0.000
# >epoch=16, lrate=0.100, error=0.000
# >epoch=17, lrate=0.100, error=0.000
# >epoch=18, lrate=0.100, error=0.000
# >epoch=19, lrate=0.100, error=0.000
# -0.222838692183 0.146581461569 1.16963272862

# %%
### Bias is --0.52410090239204921, weight1 is 0.31298865660014469 and weight2 is 0.87420030831763573 for dataSet 4

# %%
plt.plot(data_set_4['X1'], -(bias_4/w2_4) -((w1_4*data_set_4['X1'])/w2_4), color='red')
plt.scatter(data_set_4['X1'], data_set_4['X2'], c = data_set_4['Y'])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Feature Plot X1 vs X2')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## can't be linearly separable
